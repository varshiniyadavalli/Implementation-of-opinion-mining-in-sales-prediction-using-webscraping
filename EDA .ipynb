# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
cd=pd.read_csv("products.csv")

# %%
cd
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
cd['display'][:2]
# Out:
# 0    14 inch, Icicle Gold, 1.4 kg
# 1      14 inch, Gun Metal, 1.4 kg
# Name: display, dtype: object

# %%
cd['screen size']=cd['display'].str[:4]

# %%
cd
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
screensize=cd['screen size'].str.replace('i',' ')

# %%
screensize
# Out:
# 0     14
# 1     14
# 2     13.3
# 3     15.6
# 4     14
# 5     15.6
# 6     15.6
# 7     14
# 8     14
# 9     14
# 10    15.6
# 11    15.6
# 12    15.6
# 13    15.6
# 14    14
# 15    14
# 16    15.6
# 17    15.6
# 18    15.6
# 19    15.6
# 20    14
# 21    15.6
# 22    15.6
# 23    15.6
# 24    15.6
# 25    14
# 26    14
# 27    15.6
# 28    15.6
# 29    14
# 30    15.6
# 31    15.6
# 32    15.6
# 33    15.6
# 34    14
# 35    14
# 36    15.6
# 37    14
# 38    14
# 39    14
# Name: screen size, dtype: object

# %%
cd['screen size']=screensize

# %%
cd
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
cd.drop(['screen size'],axis=1)
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
screensize=[14,14,13.3,15.6,14,15.6,15.6,14,14,14,15.6,15.6,15.6,15.6,14,14,
15.6,15.6,15.6,15.6,14,15.6,15.6,15.6,15.6,14,14,15.6,15.6,14,15.6,15.6,15.6,15.6,14,14,15.6,14,14,14]

# %%
cd['screen size']=screensize

# %%
cd
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
chanceofbuy = [0.89,0.89,0.78,0.89,0.79,0.75,0.73,0.69,0.73,0.8,0.85,0.89,
0.89,0.7,0.68,0.78,0.68,0.7,0.75,0.75,0.69,0.7,0.77,0.72,
0.76,0.74,0.65,0.72,0.75,0.72,0.65,0.7,0.7,0.71,0.69,0.63,
0.62,0.59,0.6,0.71]

# %%
cd['chance of buy']= chanceofbuy

# %%
cd
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
s=cd.drop(['display'],axis=1)

# %%
s
# Out:
#     Unnamed: 0                                       Product Name    Price  \
# 0            0  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 1            1  Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0
# 2            2  Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0
# 3            3  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0
# 4            4  Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0
# 5            5  Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0
# 6            6  Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0
# 7            7  HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0
# 8            8  Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0
# 9            9  Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0
# 10          10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0
# ...

# %%
am=s.drop(['Unnamed: 0'],axis=1)

# %%
am
# Out:
#                                          Product Name    Price  rating  \
# 0   Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0     4.7
# 1   Asus VivoBook S14 Core i7 8th Gen - (8 GB/1 TB...  69990.0     4.7
# 2   Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...  61990.0     4.7
# 3   Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  26990.0     4.0
# 4   Acer Swift 3 Core i5 8th Gen - (8 GB/512 GB SS...  54990.0     4.6
# 5   Lenovo Ideapad S145 APU Dual Core A6 - (4 GB/1...  20999.0     4.0
# 6   Lenovo Ideapad 130 APU Dual Core A6 - (4 GB/1 ...  19990.0     3.9
# 7   HP 14q APU Dual Core A9 - (4 GB/256 GB SSD/Win...  19990.0     4.1
# 8   Asus VivoBook 14 Core i3 7th Gen - (4 GB/256 G...  33990.0     4.3
# 9   Asus VivoBook S Series Core i5 8th Gen - (8 GB...  51990.0     4.5
# 10  Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/...  25990.0     4.1
# 11  Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 T...  27990.0     4.0
# ...

# %%
ad=am.drop(['Product Name'],axis=1)

# %%
ad
# Out:
#       Price  rating  discount  screen size  chance of buy
# 0   69990.0     4.7        29         14.0           0.89
# 1   69990.0     4.7        29         14.0           0.89
# 2   61990.0     4.7        26         13.3           0.78
# 3   26990.0     4.0        30         15.6           0.89
# 4   54990.0     4.6        12         14.0           0.79
# 5   20999.0     4.0        20         15.6           0.75
# 6   19990.0     3.9        17         15.6           0.73
# 7   19990.0     4.1        18         14.0           0.69
# 8   33990.0     4.3        19         14.0           0.73
# 9   51990.0     4.5        31         14.0           0.80
# 10  25990.0     4.1        22         15.6           0.85
# 11  27990.0     4.0        15         15.6           0.89
# 12  49990.0     4.6        21         15.6           0.89
# 13  22990.0     4.1        16         15.6           0.70
# 14  31990.0     4.3         7         14.0           0.68
# ...

# %%
ad.cov()
# Out:
#                       Price       rating      discount  screen size  \
# Price          2.221159e+08  3396.566538  30332.120513 -3809.537821
# rating         3.396567e+03     0.065891      0.297051    -0.091122
# discount       3.033212e+04     0.297051     57.566667     0.412179
# screen size   -3.809538e+03    -0.091122      0.412179     0.693686
# chance of buy  4.240859e+02     0.006604      0.243449     0.007144
#
#                chance of buy
# Price             424.085936
# rating              0.006604
# discount            0.243449
# screen size         0.007144
# chance of buy       0.006297

# %%
corrdata=ad.corr()

# %%
corrdata #correlation is high for discount,price and rating the chance of buy is more dependent on this input factors
# Out:
#                   Price    rating  discount  screen size  chance of buy
# Price          1.000000  0.887845  0.268242    -0.306903       0.358593
# rating         0.887845  1.000000  0.152522    -0.426214       0.324238
# discount       0.268242  0.152522  1.000000     0.065226       0.404352
# screen size   -0.306903 -0.426214  0.065226     1.000000       0.108097
# chance of buy  0.358593  0.324238  0.404352     0.108097       1.000000

# %%
sns.pairplot(ad[['Price','rating','discount','screen size','chance of buy']])#chance of buy is more dependent on rating

# %%
ad.boxplot(column='rating',by='chance of buy')#high rating high chance of rating

# %%
ad.boxplot(column='discount',by='chance of buy')# chance of buy is max for discount of 35 %

# %%
ad.boxplot(column='Price',by='chance of buy')

# %%
ad.describe()
# Out:
#               Price     rating  discount  screen size  chance of buy
# count     40.000000  40.000000  40.00000    40.000000      40.000000
# mean   40342.950000   4.297500  20.85000    14.862500       0.735750
# std    14903.551817   0.256692   7.58727     0.832878       0.079353
# min    17090.000000   3.800000   5.00000    13.300000       0.590000
# 25%    27665.000000   4.100000  15.75000    14.000000       0.690000
# 50%    39990.000000   4.300000  21.50000    15.600000       0.720000
# 75%    51990.000000   4.500000  26.00000    15.600000       0.772500
# max    69990.000000   4.700000  39.00000    15.600000       0.890000

# %%
x = ad[['Price','rating','discount','screen size']]
y = ad["chance of buy"]
# Split the data into Training set and Test set
from sklearn.model_selection import train_test_split  #train_test_split splits arrays or matrices into random train and test subsets. 
x_train, x_test, y_train, y_test = train_test_split(x, y,train_size=0.3,random_state=1) 
#random_state=some_number,guarantees that the output of Run 1 will be equal to the output of Run 2, 
# i.e. split will be always the same.
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(x_train,y_train)
accuracy = model.score(x_train, y_train)
print('Accuracy of the train model:', accuracy)
# Out:
# Accuracy of the train model: 0.7389646350109763

# %%
x=ad.iloc[:,0:4]
y=ad.iloc[:,4]

# %%
x
# Out:
#       Price  rating  discount  screen size
# 0   69990.0     4.7        29         14.0
# 1   69990.0     4.7        29         14.0
# 2   61990.0     4.7        26         13.3
# 3   26990.0     4.0        30         15.6
# 4   54990.0     4.6        12         14.0
# 5   20999.0     4.0        20         15.6
# 6   19990.0     3.9        17         15.6
# 7   19990.0     4.1        18         14.0
# 8   33990.0     4.3        19         14.0
# 9   51990.0     4.5        31         14.0
# 10  25990.0     4.1        22         15.6
# 11  27990.0     4.0        15         15.6
# 12  49990.0     4.6        21         15.6
# 13  22990.0     4.1        16         15.6
# 14  31990.0     4.3         7         14.0
# 15  51990.0     4.5        24         14.0
# 16  18999.0     3.8        17         15.6
# 17  33990.0     4.2        12         15.6
# 18  49990.0     4.5        14         15.6
# 19  39990.0     4.2        26         15.6
# 20  25490.0     4.1        13         14.0
# ...

# %%
y
# Out:
# 0     0.89
# 1     0.89
# 2     0.78
# 3     0.89
# 4     0.79
# 5     0.75
# 6     0.73
# 7     0.69
# 8     0.73
# 9     0.80
# 10    0.85
# 11    0.89
# 12    0.89
# 13    0.70
# 14    0.68
# 15    0.78
# 16    0.68
# 17    0.70
# 18    0.75
# 19    0.75
# 20    0.69
# 21    0.70
# 22    0.77
# 23    0.72
# 24    0.76
# 25    0.74
# 26    0.65
# 27    0.72
# 28    0.75
# 29    0.72
# 30    0.65
# 31    0.70
# 32    0.70
# 33    0.71
# 34    0.69
# 35    0.63
# 36    0.62
# 37    0.59
# 38    0.60
# 39    0.71
# Name: chance of buy, dtype: float64

# %% [markdown]
# # decision tree

# %%
#Decision Tree Classifier
from sklearn.tree import DecisionTreeRegressor
decission = DecisionTreeRegressor()
decission.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
accuracy=decission.score(x_train,y_train)
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 1.0

# %%
y_train_prediction = decission.predict(x_train)

# %%
y_train_prediction
# Out:
# array([0.69, 0.6 , 0.89, 0.68, 0.89, 0.78, 0.75, 0.89, 0.8 , 0.73, 0.89,
#        0.59])

# %%
# model evaluation for training set
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
rmse_training = (np.sqrt(mean_squared_error(y_train, y_train_prediction)))
r2_training = r2_score(y_train, y_train_prediction)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse_training))
print('R2 score is {}'.format(r2_training))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 0.0
# R2 score is 1.0
